# %% [markdown]
# <a href="https://colab.research.google.com/github/rahuldabbeta/Video_game_sales/blob/main/Video_Game_Sales_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #***VIDEO GAME SALES***
# #---------------------------------

# %% [markdown]
# ## **DESCRIPTION**

# %% [markdown]
# This dataset contains a list of video games with sales greater than 100,000 copies. It was generated by a scrape of [vgchartz.com](https://www.vgchartz.com/).
#
# Fields include
#
# Rank - Ranking of overall sales
#
# Name - The games name
#
# Platform - Platform of the games release (i.e. PC,PS4, etc.)
#
# Year - Year of the game's release
#
# Genre - Genre of the game
#
# Publisher - Publisher of the game
#
# NA_Sales - Sales in North America (in millions)
#
# EU_Sales - Sales in Europe (in millions)
#
# JP_Sales - Sales in Japan (in millions)
#
# Other_Sales - Sales in the rest of the world (in millions)
#
# Global_Sales - Total worldwide sales.
#
# The script to scrape the data is available at https://github.com/GregorUT/vgchartzScrape.
# It is based on BeautifulSoup using Python.
# There are 16,598 records. 2 records were dropped due to incomplete information.

# %% [markdown]
# ## **QUESTIONS TO BE ANSWERED**

# %% [markdown]
# * Find the different main stream platforms availabe for game release.
# * Find the different genres of the video games.
# * Evaluate the sales over the years for global, North America, Europe, Japan and Other Markets.
# * Evaluate the sales based on genre for global, North America, Europe, Japan and Other Markets.
# * Find the top publishers in the world, North America, Europe, Japan and other markets.
# * Find the popular platforms in the world, North America, Europe, Japan and other markets.
# * Find the popular games in the world, North America, Europe, Japan and other markets.
# * What is the market distribution of countries in video game sales?
# * Is there a relation between number of games publishing and the profit gained by publishers
# * How many games are coming down each year?
# * Over the last decade, what are the market distribution,sales in years,sales by genre and game release?
# * Over the last decade, which are the popular platforms,publishers, and games?

# %% [markdown]
# ##**IMPORTING ALL PACKAGES**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## **CREATING A DATAFRAME FROM THE CSV FILE**

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Edubridge/DA Project/vgsales.csv')
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16598 rows x 11 columns]

# %% [markdown]
# ## **IDENTIFING THE MISSNG VALUES**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16598 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16598 non-null  int64
#  1   Name          16598 non-null  object
#  2   Platform      16598 non-null  object
#  3   Year          16327 non-null  float64
#  4   Genre         16598 non-null  object
#  5   Publisher     16540 non-null  object
#  6   NA_Sales      16598 non-null  float64
#  7   EU_Sales      16598 non-null  float64
#  8   JP_Sales      16598 non-null  float64
#  9   Other_Sales   16598 non-null  float64
#  10  Global_Sales  16598 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.4+ MB

# %%
df.isnull().sum()[df.isnull().sum() !=0]
# Out:
# Year         271
# Publisher     58
# dtype: int64

# %%
df[df.Year.isnull()]
# Out:
#         Rank                         Name  ... Other_Sales  Global_Sales
# 179      180              Madden NFL 2004  ...        0.71          5.23
# 377      378             FIFA Soccer 2004  ...        0.51          3.49
# 431      432   LEGO Batman: The Videogame  ...        0.29          3.17
# 470      471   wwe Smackdown vs. Raw 2006  ...        0.41          3.00
# 607      608               Space Invaders  ...        0.03          2.53
# ...      ...                          ...  ...         ...           ...
# 16307  16310                Freaky Flyers  ...        0.00          0.01
# 16327  16330                    Inversion  ...        0.00          0.01
# 16366  16369  Hakuouki: Shinsengumi Kitan  ...        0.00          0.01
# 16427  16430                 Virtua Quest  ...        0.00          0.01
# 16493  16496                   The Smurfs  ...        0.00          0.01
#
# [271 rows x 11 columns]

# %%
df[df.Publisher.isnull()]
# Out:
#         Rank  ... Global_Sales
# 470      471  ...         3.00
# 1303    1305  ...         1.46
# 1662    1664  ...         1.21
# 2222    2224  ...         0.93
# 3159    3161  ...         0.64
# 3166    3168  ...         0.64
# 3766    3768  ...         0.53
# 4145    4147  ...         0.48
# 4526    4528  ...         0.43
# 4635    4637  ...         0.42
# 5302    5304  ...         0.35
# 5647    5649  ...         0.32
# 6272    6274  ...         0.27
# 6437    6439  ...         0.27
# 6562    6564  ...         0.26
# 6648    6650  ...         0.25
# 6849    6851  ...         0.24
# 7208    7210  ...         0.22
# 7351    7353  ...         0.21
# 7470    7472  ...         0.21
# 7953    7955  ...         0.19
# 8330    8332  ...         0.17
# 8341    8343  ...         0.17
# 8368    8370  ...         0.17
# 8503    8505  ...         0.16
# 8770    8772  ...         0.15
# 8848    8850  ...         0.15
# 8896    8898  ...         0.15
# 9517    9519  ...         0.13
# ...

# %% [markdown]
# ## **CLEANING THE DATA**

# %%
df.dropna(axis=0,inplace=True)
df.shape
# Out:
# (16291, 11)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  float64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
df.sample(5)
# Out:
#       Rank                               Name  ... Other_Sales  Global_Sales
# 2568  2570                         Moto Racer  ...        0.05          0.80
# 1798  1800                      Guitar Hero 5  ...        0.11          1.14
# 9993  9995  Dead Island Definitive Collection  ...        0.02          0.12
# 1092  1094   StarCraft II: Heart of the Swarm  ...        0.19          1.67
# 6410  6412           Battle Arena Toshinden 3  ...        0.02          0.27
#
# [5 rows x 11 columns]

# %%
year = [int(x) for x in list(df.Year)]
df.Year = year
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16291 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  int64
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int64(2), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# Year is a catogorical variable. But it is considered as an integer here. So we need to change its the datatype.

# %%
df = df.astype({'Year':str})
df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          2  ...        40.24
# 2          3  ...        35.82
# 3          4  ...        33.00
# 4          5  ...        31.37
# ...      ...  ...          ...
# 16593  16596  ...         0.01
# 16594  16597  ...         0.01
# 16595  16598  ...         0.01
# 16596  16599  ...         0.01
# 16597  16600  ...         0.01
#
# [16291 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16291 entries, 0 to 16597
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Rank          16291 non-null  int64
#  1   Name          16291 non-null  object
#  2   Platform      16291 non-null  object
#  3   Year          16291 non-null  object
#  4   Genre         16291 non-null  object
#  5   Publisher     16291 non-null  object
#  6   NA_Sales      16291 non-null  float64
#  7   EU_Sales      16291 non-null  float64
#  8   JP_Sales      16291 non-null  float64
#  9   Other_Sales   16291 non-null  float64
#  10  Global_Sales  16291 non-null  float64
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# ## **EXPLORATORY DATA ANALYSIS**

# %% [markdown]
# ##*PLATFORMS FOR VIDEO GAMES RELEASE*

# %%
print(df.Platform.unique())
len(df.Platform.unique())
# Out:
# ['Wii' 'NES' 'GB' 'DS' 'X360' 'PS3' 'PS2' 'SNES' 'GBA' '3DS' 'PS4' 'N64'
#  'PS' 'XB' 'PC' '2600' 'PSP' 'XOne' 'GC' 'WiiU' 'GEN' 'DC' 'PSV' 'SAT'
#  'SCD' 'WS' 'NG' 'TG16' '3DO' 'GG' 'PCFX']
# 31

# %% [markdown]
# > *There are around 31 main stream platforms in the world for video game.*
# >
# >---
# > *Wii, NES, GB, DS, X360, PS3, PS2, SNES, GBA, 3DS, PS4, N64,PS, XB, PC, 2600, PSP, XOne, GC, WiiU, GEN, DC, PSV, SAT,SCD, WS, NG, TG16, 3DO, GG, PCFX.*
# >

# %% [markdown]
# ##*TYPES OF VIDEO GAME GENRE*

# %%
print(df.Genre.unique())
len(df.Genre.unique())
# Out:
# ['Sports' 'Platform' 'Racing' 'Role-Playing' 'Puzzle' 'Misc' 'Shooter'
#  'Simulation' 'Action' 'Fighting' 'Adventure' 'Strategy']
# 12

# %% [markdown]
# > | *The Common Genres*|             |
# > |-------------|------------------|
# > | Sports      |    Platform      |
# > | Racing      |    Role-Playing  |
# > | Puzzle      |    Misc          |
# > | Shooter     |    Simulation    |
# > | Action      |    Fighting      |
# > | Adventure   |    Strategy      |

# %% [markdown]
# ##*GLOBAL MARKET*

# %% [markdown]
# ###GLOBAL SALES IN YEARS

# %%
global_sales_year = df.groupby('Year')['Global_Sales'].sum().reset_index()
global_sales_year
# Out:
#     Year  Global_Sales
# 0   1980         11.38
# 1   1981         35.77
# 2   1982         28.86
# 3   1983         16.79
# 4   1984         50.36
# 5   1985         53.94
# 6   1986         37.07
# 7   1987         21.74
# 8   1988         47.22
# 9   1989         73.45
# 10  1990         49.39
# 11  1991         32.23
# 12  1992         76.16
# 13  1993         45.98
# 14  1994         79.17
# 15  1995         88.11
# 16  1996        199.15
# 17  1997        200.98
# 18  1998        256.47
# 19  1999        251.27
# 20  2000        201.56
# 21  2001        331.47
# 22  2002        395.52
# 23  2003        357.85
# 24  2004        414.01
# 25  2005        458.51
# 26  2006        521.04
# 27  2007        609.92
# 28  2008        678.90
# 29  2009        667.30
# 30  2010        600.29
# 31  2011        515.80
# 32  2012        363.49
# 33  2013        368.11
# 34  2014        337.03
# 35  2015        264.44
# 36  2016         70.90
# 37  2017          0.05
# 38  2020          0.29

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'Global_Sales', data = global_sales_year)
plt.title('Global Sales over the Years')
plt.xticks(rotation = 90)
plt.savefig('Global Sales over the Years')
plt.show()

# %% [markdown]
# > *From the above plot we can see that the global video game sales started increasing from 1996.*
# >
# > *In 2008, nearly 700 million games were sold out. After that there has been a short downfall in the industry.*
# >
# >*We can consider 1996 to 2015 as the golden age of video games*

# %% [markdown]
# ###GLOBAL SALES BASES ON GENRE

# %%
global_sales_genre = df.groupby('Genre')['Global_Sales'].sum().reset_index()
global_sales_genre
# Out:
#            Genre  Global_Sales
# 0         Action       1722.84
# 1      Adventure        234.59
# 2       Fighting        444.05
# 3           Misc        789.87
# 4       Platform        829.13
# 5         Puzzle        242.21
# 6         Racing        726.76
# 7   Role-Playing        923.83
# 8        Shooter       1026.20
# 9     Simulation        389.98
# 10        Sports       1309.24
# 11      Strategy        173.27

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'Genre', y = 'Global_Sales', data= global_sales_genre)
plt.xticks(rotation= 45)
plt.title('Global Sales vs Genre')
plt.savefig('Global Sales vs Genre')
plt.show()

# %% [markdown]
# > *We can see that most popular genre of games are the Action games, then comes the sports.*
# >
# > *Strategic, puzzle and Adventure games were the least sold genres in the gaming world.*

# %% [markdown]
# ###TOP 10 GLOBAL PLATFORMS

# %%
top_global_platforms = df.groupby('Platform')['Global_Sales'].sum().reset_index().sort_values('Global_Sales',ascending=False).head(10).reset_index(drop = True)
top_global_platforms
# Out:
#   Platform  Global_Sales
# 0      PS2       1233.46
# 1     X360        969.60
# 2      PS3        949.35
# 3      Wii        909.81
# 4       DS        818.91
# 5       PS        727.39
# 6      GBA        305.62
# 7      PSP        291.71
# 8      PS4        278.10
# 9       PC        254.70

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'Global_Sales',x = 'Platform', data = top_global_platforms)
plt.title('Top 10 Global Platforms')
plt.savefig('Top 10 Global Platforms')
plt.show()

# %% [markdown]
# > *From the 31 main stream platforms , there are the top ten platforms in the world for video game release.*
# >
# > *Among these , PS2 holds holds the maximum sales in the global market with more than 1200 millions  followed by X360 with nearly 1000 million sales.*

# %% [markdown]
# ###TOP 10 PUBLISHERS IN THE WORLD

# %%
top_global_publishers = df.groupby('Publisher')['Global_Sales'].sum().reset_index().sort_values('Global_Sales',ascending=False).head(10).reset_index(drop=True)
top_global_publishers
# Out:
#                       Publisher  Global_Sales
# 0                      Nintendo       1784.43
# 1               Electronic Arts       1093.39
# 2                    Activision        721.41
# 3   Sony Computer Entertainment        607.28
# 4                       Ubisoft        473.54
# 5          Take-Two Interactive        399.30
# 6                           THQ        340.44
# 7  Konami Digital Entertainment        278.56
# 8                          Sega        270.70
# 9            Namco Bandai Games        253.65

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'Global_Sales', data= top_global_publishers)
plt.title('Top 10 Publishers in the world',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the world',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Nintendo is the leading publisher in the world market with a lead of around 700 million sales than Electronic Arts,the second leading publisher*

# %% [markdown]
# ###TOP 10 GAMES IN THE WORLD

# %%
top_games = df.head(10)[['Rank','Name','Global_Sales']]
top_games
# Out:
#    Rank                       Name  Global_Sales
# 0     1                 Wii Sports         82.74
# 1     2          Super Mario Bros.         40.24
# 2     3             Mario Kart Wii         35.82
# 3     4          Wii Sports Resort         33.00
# 4     5   Pokemon Red/Pokemon Blue         31.37
# 5     6                     Tetris         30.26
# 6     7      New Super Mario Bros.         30.01
# 7     8                   Wii Play         29.02
# 8     9  New Super Mario Bros. Wii         28.62
# 9    10                  Duck Hunt         28.31

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'Global_Sales', data = top_games)
plt.title('Top 10 games in the Global Market',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in the Global Market',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Wii Sports is the most popular game in the global market*
# >
# > *Super Mario is the second in place but only with half the sales of wii sports*

# %% [markdown]
# ##*NORTH AMERICA*

# %% [markdown]
# ###SALES IN NORTH AMERICA OVER THE YEARS

# %%
na_sales_yr = df.groupby('Year')['NA_Sales'].sum().reset_index()
na_sales_yr
# Out:
#     Year  NA_Sales
# 0   1980     10.59
# 1   1981     33.40
# 2   1982     26.92
# 3   1983      7.76
# 4   1984     33.28
# 5   1985     33.73
# 6   1986     12.50
# 7   1987      8.46
# 8   1988     23.87
# 9   1989     45.15
# 10  1990     25.46
# 11  1991     12.76
# 12  1992     33.87
# 13  1993     15.12
# 14  1994     28.15
# 15  1995     24.82
# 16  1996     86.76
# 17  1997     94.75
# 18  1998    128.36
# 19  1999    126.06
# 20  2000     94.49
# 21  2001    173.98
# 22  2002    216.19
# 23  2003    193.59
# 24  2004    218.80
# 25  2005    241.58
# 26  2006    263.12
# 27  2007    311.18
# 28  2008    351.44
# 29  2009    338.85
# 30  2010    304.24
# 31  2011    241.00
# 32  2012    154.93
# 33  2013    154.77
# 34  2014    131.97
# 35  2015    102.82
# 36  2016     22.66
# 37  2017      0.00
# 38  2020      0.27

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'NA_Sales', data = na_sales_yr,color='blue')
plt.title('North America Sales over the Years',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('North America Sales over the Years',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *The sale rate in North America is very much identical to global sales. As North America being the largest market, it is not surprising.*

# %% [markdown]
# ###SALES IN NORTH AMERICA BASED ON GENRE

# %%
na_sales_gnr = df.groupby('Genre')['NA_Sales'].sum().reset_index()
na_sales_gnr
# Out:
#            Genre  NA_Sales
# 0         Action    861.77
# 1      Adventure    101.93
# 2       Fighting    220.74
# 3           Misc    396.92
# 4       Platform    445.99
# 5         Puzzle    122.01
# 6         Racing    356.93
# 7   Role-Playing    326.50
# 8        Shooter    575.16
# 9     Simulation    181.78
# 10        Sports    670.09
# 11      Strategy     67.83

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Genre', y = 'NA_Sales', data = na_sales_gnr,color='blue')
plt.title('Sales in North America based on genre',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Sales in North America based on genre',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *It is also identical to the global values which is also predicatable*

# %% [markdown]
# ###TOP 10 PLATFORMS IN NORTH AMERICA

# %%
top_na_platforms = df.groupby('Platform')['NA_Sales'].sum().reset_index().sort_values('NA_Sales',ascending=False).head(10).reset_index(drop = True)
top_na_platforms
# Out:
#   Platform  NA_Sales
# 0     X360    594.33
# 1      PS2    572.92
# 2      Wii    497.37
# 3      PS3    388.90
# 4       DS    388.53
# 5       PS    334.71
# 6       XB    182.06
# 7      GBA    178.43
# 8      N64    138.91
# 9       GC    131.94

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'NA_Sales',x = 'Platform', data = top_na_platforms,color='blue')
plt.title('Top 10 platforms in North America',fontsize=20)
plt.savefig('Top 10 platforms in North America',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *When compared to the insights from global market , x360 is widely used in North America. Still we can see that there is not much different in numbers of ps2 and x360*

# %% [markdown]
# ###TOP 10 PUBLISHERS IN NORTH AMERICA

# %%
top_na_publishers = df.groupby('Publisher')['NA_Sales'].sum().reset_index().sort_values('NA_Sales',ascending=False).head(10).reset_index(drop=True)
top_na_publishers
# Out:
#                      Publisher  NA_Sales
# 0                     Nintendo    815.75
# 1              Electronic Arts    584.22
# 2                   Activision    426.01
# 3  Sony Computer Entertainment    265.22
# 4                      Ubisoft    252.81
# 5         Take-Two Interactive    220.47
# 6                          THQ    208.60
# 7       Microsoft Game Studios    155.35
# 8                         Sega    108.78
# 9                        Atari    101.23

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'NA_Sales', data= top_na_publishers,color='blue')
plt.title('Top 10 Publishers in the North America',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the North America',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Again similar to the global market , Nintendo is the popular publisher folllowed by Electronic Arts and Activision.*

# %% [markdown]
# ###TOP 10 GAMES IN NORTH AMERICA

# %%
top_games_na = df.head(10)[['Rank','Name','NA_Sales']]
top_games_na
# Out:
#    Rank                       Name  NA_Sales
# 0     1                 Wii Sports     41.49
# 1     2          Super Mario Bros.     29.08
# 2     3             Mario Kart Wii     15.85
# 3     4          Wii Sports Resort     15.75
# 4     5   Pokemon Red/Pokemon Blue     11.27
# 5     6                     Tetris     23.20
# 6     7      New Super Mario Bros.     11.38
# 7     8                   Wii Play     14.03
# 8     9  New Super Mario Bros. Wii     14.59
# 9    10                  Duck Hunt     26.93

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'NA_Sales', data = top_games_na,color='blue')
plt.title('Top 10 games in North America',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in North America',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *In North America , Duck hunt and Tennis is more popular than Mario Kart. Wii Sports and Super Mario remains as the top games just like in the global level.*

# %% [markdown]
# ##*JAPAN*

# %% [markdown]
# ###SALES IN JAPAN OVER THE YEARS

# %%
jp_sales_yr = df.groupby('Year')['JP_Sales'].sum().reset_index()
jp_sales_yr
# Out:
#     Year  JP_Sales
# 0   1980      0.00
# 1   1981      0.00
# 2   1982      0.00
# 3   1983      8.10
# 4   1984     14.27
# 5   1985     14.56
# 6   1986     19.81
# 7   1987     11.63
# 8   1988     15.76
# 9   1989     18.36
# 10  1990     14.88
# 11  1991     14.78
# 12  1992     28.91
# 13  1993     25.33
# 14  1994     33.99
# 15  1995     45.75
# 16  1996     57.44
# 17  1997     48.87
# 18  1998     50.04
# 19  1999     52.34
# 20  2000     42.77
# 21  2001     39.86
# 22  2002     41.76
# 23  2003     34.20
# 24  2004     41.65
# 25  2005     54.28
# 26  2006     73.73
# 27  2007     60.29
# 28  2008     60.26
# 29  2009     61.89
# 30  2010     59.49
# 31  2011     53.04
# 32  2012     51.74
# 33  2013     47.59
# 34  2014     39.46
# 35  2015     33.72
# 36  2016     13.67
# 37  2017      0.05
# 38  2020      0.00

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'JP_Sales', data = jp_sales_yr,color='green')
plt.title('Sales over the Years in Japan',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Sales over the Years in Japan',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *In Japan, video games sales rate started increasing since the early 90's.*

# %% [markdown]
# ###SALES IN JAPAN BASED ON GENRE

# %%
jp_sales_gnr = df.groupby('Genre')['JP_Sales'].sum().reset_index()
jp_sales_gnr
# Out:
#            Genre  JP_Sales
# 0         Action    158.65
# 1      Adventure     51.99
# 2       Fighting     87.15
# 3           Misc    106.67
# 4       Platform    130.65
# 5         Puzzle     56.68
# 6         Racing     56.61
# 7   Role-Playing    350.29
# 8        Shooter     38.18
# 9     Simulation     63.54
# 10        Sports    134.76
# 11      Strategy     49.10

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Genre', y = 'JP_Sales', data = jp_sales_gnr,color='green')
plt.title('Sales in Japan based on genre',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Sales in Japan based on genre',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *In Japan, role playing games are the most widely played genre.Action games are the second popular one but with less than half the sales of RPG.*

# %% [markdown]
# ###TOP 10 PLATFORMS IN JAPAN

# %%
top_jp_platforms = df.groupby('Platform')['JP_Sales'].sum().reset_index().sort_values('JP_Sales',ascending=False).head(10).reset_index(drop = True)
top_jp_platforms
# Out:
#   Platform  JP_Sales
# 0       DS    175.02
# 1       PS    139.78
# 2      PS2    137.54
# 3     SNES    116.55
# 4      NES     98.65
# 5      3DS     97.30
# 6       GB     85.12
# 7      PS3     79.21
# 8      PSP     75.89
# 9      Wii     68.28

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'JP_Sales',x = 'Platform', data = top_jp_platforms,color='green')
plt.title('Top 10 platforms in Japan',fontsize=20)
plt.savefig('Top 10 platforms in Japan',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *DS is the widely used platform in Japan followed by the playstation.*

# %% [markdown]
# ###TOP 10 PUBLISHERS IN JAPAN

# %%
top_jp_publishers = df.groupby('Publisher')['JP_Sales'].sum().reset_index().sort_values('JP_Sales',ascending=False).head(10).reset_index(drop=True)
top_jp_publishers
# Out:
#                       Publisher  JP_Sales
# 0                      Nintendo    454.99
# 1            Namco Bandai Games    126.84
# 2  Konami Digital Entertainment     90.93
# 3   Sony Computer Entertainment     74.10
# 4                        Capcom     67.38
# 5                          Sega     56.19
# 6                   Square Enix     49.79
# 7                    SquareSoft     40.13
# 8              Enix Corporation     32.40
# 9                    Tecmo Koei     29.21

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'JP_Sales', data= top_jp_publishers,color='green')
plt.title('Top 10 Publishers in the Japan',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the Japan',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *The popularity of Nintendo in Japna Market is remarkably high. As a Japanese company and their popular major console is Nintendo DC , it is not that much of a surprise to see them as the top in japanese market.*

# %% [markdown]
# ###TOP 10 GAMES IN JAPAN

# %%
top_games_jp = df.head(10)[['Rank','Name','JP_Sales']]
top_games_jp
# Out:
#    Rank                       Name  JP_Sales
# 0     1                 Wii Sports      3.77
# 1     2          Super Mario Bros.      6.81
# 2     3             Mario Kart Wii      3.79
# 3     4          Wii Sports Resort      3.28
# 4     5   Pokemon Red/Pokemon Blue     10.22
# 5     6                     Tetris      4.22
# 6     7      New Super Mario Bros.      6.50
# 7     8                   Wii Play      2.93
# 8     9  New Super Mario Bros. Wii      4.70
# 9    10                  Duck Hunt      0.28

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'JP_Sales', data = top_games_jp,color='green')
plt.title('Top 10 games in Japan',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in Japan',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Pokemon being the top game , Super mario secures the second place in japanese market.*

# %% [markdown]
# ##*EUROPE*

# %% [markdown]
# ###SALES IN EUROPE OVER THE YEARS

# %%
eu_sales_yr = df.groupby('Year')['EU_Sales'].sum().reset_index()
eu_sales_yr
# Out:
#     Year  EU_Sales
# 0   1980      0.67
# 1   1981      1.96
# 2   1982      1.65
# 3   1983      0.80
# 4   1984      2.10
# 5   1985      4.74
# 6   1986      2.84
# 7   1987      1.41
# 8   1988      6.59
# 9   1989      8.44
# 10  1990      7.63
# 11  1991      3.95
# 12  1992     11.71
# 13  1993      4.65
# 14  1994     14.88
# 15  1995     14.90
# 16  1996     47.26
# 17  1997     48.32
# 18  1998     66.90
# 19  1999     62.67
# 20  2000     52.75
# 21  2001     94.89
# 22  2002    109.74
# 23  2003    103.81
# 24  2004    105.92
# 25  2005    121.56
# 26  2006    129.24
# 27  2007    160.18
# 28  2008    184.40
# 29  2009    191.59
# 30  2010    176.57
# 31  2011    167.31
# 32  2012    118.76
# 33  2013    125.80
# 34  2014    125.63
# 35  2015     97.71
# 36  2016     26.76
# 37  2017      0.00
# 38  2020      0.00

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'EU_Sales', data = eu_sales_yr,color='orange')
plt.title('Sales over the Years in Europe',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Sales over the Years in Europe',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *In Europe the sales gained its pace during the mid 90's.*

# %% [markdown]
# ###SALES IN EUROPE BASED ON GENRE

# %%
eu_sales_gnr = df.groupby('Genre')['EU_Sales'].sum().reset_index()
eu_sales_gnr
# Out:
#            Genre  EU_Sales
# 0         Action    516.48
# 1      Adventure     63.74
# 2       Fighting    100.00
# 3           Misc    211.77
# 4       Platform    200.65
# 5         Puzzle     50.52
# 6         Racing    236.31
# 7   Role-Playing    187.57
# 8        Shooter    310.45
# 9     Simulation    113.02
# 10        Sports    371.34
# 11      Strategy     44.84

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Genre', y = 'EU_Sales', data = eu_sales_gnr,color='orange')
plt.title('Sales in Europe based on genre',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Sales in Europe based on genre',bbox_inches='tight')
plt.show()

# %% [markdown]
# >*Similar to what we find in Global market , here also Action games are more popular and sports and shooter follows.*

# %% [markdown]
# ###TOP 10 PLATFORMS IN EUROPE

# %%
top_eu_platforms = df.groupby('Platform')['EU_Sales'].sum().reset_index().sort_values('EU_Sales',ascending=False).head(10).reset_index(drop = True)
top_eu_platforms
# Out:
#   Platform  EU_Sales
# 0      PS3    340.47
# 1      PS2    332.63
# 2     X360    278.00
# 3      Wii    264.35
# 4       PS    212.38
# 5       DS    194.05
# 6       PC    137.35
# 7      PS4    123.70
# 8      GBA     72.49
# 9      PSP     67.16

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'EU_Sales',x = 'Platform', data = top_eu_platforms,color='orange')
plt.title('Top 10 platforms in Europe',fontsize=20)
plt.savefig('Top 10 platforms in Europe',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Playstations have the popularity in Europe Market.5 of the top 10 platforms are different versions of playstation.*

# %% [markdown]
# ###TOP 10 PUBLISHERS IN EUROPE

# %%
top_eu_publishers = df.groupby('Publisher')['EU_Sales'].sum().reset_index().sort_values('EU_Sales',ascending=False).head(10).reset_index(drop=True)
top_eu_publishers
# Out:
#                       Publisher  EU_Sales
# 0                      Nintendo    418.30
# 1               Electronic Arts    367.38
# 2                    Activision    213.72
# 3   Sony Computer Entertainment    187.55
# 4                       Ubisoft    163.03
# 5          Take-Two Interactive    117.95
# 6                           THQ     94.60
# 7                          Sega     81.41
# 8  Konami Digital Entertainment     68.62
# 9        Microsoft Game Studios     68.61

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'EU_Sales', data= top_eu_publishers,color='orange')
plt.title('Top 10 Publishers in the Europe',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the Europe',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Nintendo , Electronic Arts, Activision are the top 3 publisher in Europe.*

# %% [markdown]
# ###TOP 10 GAMES IN EUROPE

# %%
top_games_eu = df.head(10)[['Rank','Name','EU_Sales']]
top_games_eu
# Out:
#    Rank                       Name  EU_Sales
# 0     1                 Wii Sports     29.02
# 1     2          Super Mario Bros.      3.58
# 2     3             Mario Kart Wii     12.88
# 3     4          Wii Sports Resort     11.01
# 4     5   Pokemon Red/Pokemon Blue      8.89
# 5     6                     Tetris      2.26
# 6     7      New Super Mario Bros.      9.23
# 7     8                   Wii Play      9.20
# 8     9  New Super Mario Bros. Wii      7.06
# 9    10                  Duck Hunt      0.63

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'EU_Sales', data = top_games_eu,color='orange')
plt.title('Top 10 games in Europe',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in Europe',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Here also wii sports are the top selling games. But unlike in North America , Mario Kart and Wii Sports Resort follows.*

# %% [markdown]
# ##*OTHER MARKETS*

# %% [markdown]
# ###SALES OVER THE YEARS IN OTHER MARKETS

# %%
other_sales_yr = df.groupby('Year')['Other_Sales'].sum().reset_index()
other_sales_yr
# Out:
#     Year  Other_Sales
# 0   1980         0.12
# 1   1981         0.32
# 2   1982         0.31
# 3   1983         0.14
# 4   1984         0.70
# 5   1985         0.92
# 6   1986         1.93
# 7   1987         0.20
# 8   1988         0.99
# 9   1989         1.50
# 10  1990         1.40
# 11  1991         0.74
# 12  1992         1.65
# 13  1993         0.89
# 14  1994         2.20
# 15  1995         2.64
# 16  1996         7.69
# 17  1997         9.13
# 18  1998        11.03
# 19  1999        10.05
# 20  2000        11.62
# 21  2001        22.76
# 22  2002        27.28
# 23  2003        26.01
# 24  2004        47.24
# 25  2005        40.55
# 26  2006        54.43
# 27  2007        77.58
# 28  2008        82.39
# 29  2009        74.77
# 30  2010        59.90
# 31  2011        54.39
# 32  2012        37.82
# 33  2013        39.82
# 34  2014        40.02
# 35  2015        30.01
# 36  2016         7.75
# 37  2017         0.00
# 38  2020         0.02

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'Other_Sales', data = other_sales_yr,color='red')
plt.title('Sales over the Years in other markets',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Sales over the Years in other markets',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *In other markets the sales started to increase since mid 90's. The sales where where at the peak from 2007 to 2009. After that there has been a drop in the sales.*

# %% [markdown]
# ###SALES BASED ON GENRE IN OTHER MARKETS

# %%
other_sales_gnr = df.groupby('Genre')['Other_Sales'].sum().reset_index()
other_sales_gnr
# Out:
#            Genre  Other_Sales
# 0         Action       184.92
# 1      Adventure        16.70
# 2       Fighting        36.19
# 3           Misc        73.92
# 4       Platform        51.51
# 5         Puzzle        12.47
# 6         Racing        76.68
# 7   Role-Playing        59.38
# 8        Shooter       101.90
# 9     Simulation        31.36
# 10        Sports       132.65
# 11      Strategy        11.23

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Genre', y = 'Other_Sales', data = other_sales_gnr,color='red')
plt.title('Sales in other markets based on genre',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Sales in other markets based on genre',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Action, Sports and Shooter are the most played genre in the other markets.*

# %% [markdown]
# ###TOP 10 PLATFORMS IN OTHER MARKETS

# %%
top_other_platforms = df.groupby('Platform')['Other_Sales'].sum().reset_index().sort_values('Other_Sales',ascending=False).head(10).reset_index(drop = True)
top_other_platforms
# Out:
#   Platform  Other_Sales
# 0      PS2       190.47
# 1      PS3       140.81
# 2     X360        84.67
# 3      Wii        79.20
# 4       DS        60.29
# 5      PS4        43.36
# 6      PSP        41.52
# 7       PS        40.69
# 8       PC        24.33
# 9      3DS        12.55

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'Other_Sales',x = 'Platform', data = top_other_platforms,color='red')
plt.title('Top 10 platforms in Other Markets',fontsize=20)
plt.savefig('Top 10 platforms in Other Markets',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Playstations are the widely used platforms in the rest of the market also.*

# %% [markdown]
# ###TOP 10 PUBLISHERS IN OTHER MARKETS

# %%
top_other_publishers = df.groupby('Publisher')['Other_Sales'].sum().reset_index().sort_values('Other_Sales',ascending=False).head(10).reset_index(drop=True)
top_other_publishers
# Out:
#                       Publisher  Other_Sales
# 0               Electronic Arts       127.63
# 1                      Nintendo        95.19
# 2   Sony Computer Entertainment        80.40
# 3                    Activision        74.79
# 4          Take-Two Interactive        55.20
# 5                       Ubisoft        50.16
# 6                           THQ        32.11
# 7  Konami Digital Entertainment        29.91
# 8                          Sega        24.30
# 9        Microsoft Game Studios        18.56

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'Other_Sales', data= top_other_publishers,color='red')
plt.title('Top 10 Publishers in the Other Markets',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the Markets',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Different fromt the major markets, Electronic Arts are the popular publishers in the rest of the market by pushing back Nintendo to second.*

# %% [markdown]
# ###TOP 10 GAMES IN OTHER MARKETS

# %%
top_games_other = df.head(10)[['Rank','Name','Other_Sales']]
top_games_other
# Out:
#    Rank                       Name  Other_Sales
# 0     1                 Wii Sports         8.46
# 1     2          Super Mario Bros.         0.77
# 2     3             Mario Kart Wii         3.31
# 3     4          Wii Sports Resort         2.96
# 4     5   Pokemon Red/Pokemon Blue         1.00
# 5     6                     Tetris         0.58
# 6     7      New Super Mario Bros.         2.90
# 7     8                   Wii Play         2.85
# 8     9  New Super Mario Bros. Wii         2.26
# 9    10                  Duck Hunt         0.47

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'Other_Sales', data = top_games_other,color='red')
plt.title('Top 10 games in Other Markets',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in Other Markets',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *In case of the top games,the rest of the markets also follows a similar pattern like Europe. Wii sports in the top position followed by Mario Kart Wii and Wii sports resort.*

# %% [markdown]
# ##*MARKET SALES COMPARISON OVER THE YEARS*

# %%
msc_yr_df = df.groupby('Year')[['NA_Sales','EU_Sales','JP_Sales','Other_Sales','Global_Sales']].sum().reset_index()
msc_yr_df
# Out:
#     Year  NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0   1980     10.59      0.67      0.00         0.12         11.38
# 1   1981     33.40      1.96      0.00         0.32         35.77
# 2   1982     26.92      1.65      0.00         0.31         28.86
# 3   1983      7.76      0.80      8.10         0.14         16.79
# 4   1984     33.28      2.10     14.27         0.70         50.36
# 5   1985     33.73      4.74     14.56         0.92         53.94
# 6   1986     12.50      2.84     19.81         1.93         37.07
# 7   1987      8.46      1.41     11.63         0.20         21.74
# 8   1988     23.87      6.59     15.76         0.99         47.22
# 9   1989     45.15      8.44     18.36         1.50         73.45
# 10  1990     25.46      7.63     14.88         1.40         49.39
# 11  1991     12.76      3.95     14.78         0.74         32.23
# 12  1992     33.87     11.71     28.91         1.65         76.16
# ...

# %%
plt.figure(figsize=(9,7))
sns.barplot(x = 'Year', y = 'Global_Sales', data = msc_yr_df,color='black',label='Global_Sales')
sns.barplot(x = 'Year', y = 'NA_Sales', data = msc_yr_df, color='red',label='NA_Sales')
sns.barplot(x = 'Year', y = 'EU_Sales', data = msc_yr_df,color='blue',label='EU_Sales')
sns.barplot(x = 'Year', y = 'JP_Sales', data = msc_yr_df,color='yellow',label='JP_Sales')
sns.barplot(x = 'Year', y = 'Other_Sales', data = msc_yr_df,color= 'green',label='Other_Sales')
plt.title('Sales in each market over the years')
plt.legend()
plt.xticks(rotation=90)
plt.ylabel('Sales')
plt.savefig('Sales in each market over the years')
plt.show()

# %% [markdown]
# > *Before 90's there had been significantly low sales in video games. During the early 90's Japan and North America were the first to have a growth in sales Which is understandable by Nintendo being the top publisher and North America being the largest market. Gradually sales in Europe increase and it took over japan's place in the market. There has been a growth in other markets also but in a low pace only when compard to these three markets.*

# %% [markdown]
# ##*FROM 1980 TO 2005*

# %% [markdown]
# ###DATA FROM 1980 TO 2005

# %%
dfupto2005_lst = []
for i in range(1980,2006):
  dfupto2005_lst.append(df[df.Year== str(i)])
df_upto2005 = pd.concat(dfupto2005_lst,ignore_index=True)
df_upto2005
# Out:
#        Rank                          Name  ... Other_Sales Global_Sales
# 0       259                     Asteroids  ...        0.05         4.31
# 1       545               Missile Command  ...        0.03         2.76
# 2      1768                       Kaboom!  ...        0.01         1.15
# 3      1971                      Defender  ...        0.01         1.05
# 4      2671                        Boxing  ...        0.01         0.77
# ...     ...                           ...  ...         ...          ...
# 6084  16338                   Whac-A-Mole  ...        0.00         0.01
# 6085  16354  World Snooker Challenge 2005  ...        0.00         0.01
# 6086  16442  Shin Sangoku Musou 4 Special  ...        0.00         0.01
# 6087  16445   Colin McRae Rally 2005 plus  ...        0.00         0.01
# 6088  16500          Snood 2: On Vacation  ...        0.00         0.01
#
# [6089 rows x 11 columns]

# %% [markdown]
# ###GAME RELEASE FROM 1980 TO 2005

# %%
plt.figure(figsize= (9,7))
sns.countplot(x = df_upto2005.Year.sort_values())
plt.title('Games Release up to 2005',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Games Release up to 2005',bbox_inches='tight')
plt.show()

# %% [markdown]
# ###GLOBAL SALES FROM 1980 TO 2005

# %%
gc_df = df_upto2005.Year.value_counts().to_frame().reset_index().rename(columns={'index':'Year','Year':'Count'}).sort_values('Year')
gc_df
# Out:
#     Year  Count
# 25  1980      9
# 13  1981     46
# 16  1982     36
# 18  1983     17
# 24  1984     14
# 23  1985     14
# 17  1986     21
# 21  1987     16
# 22  1988     15
# 19  1989     17
# 20  1990     16
# 15  1991     41
# 14  1992     43
# 12  1993     60
# 11  1994    121
# 10  1995    219
# 9   1996    263
# 8   1997    289
# 5   1998    379
# 7   1999    338
# 6   2000    349
# 4   2001    482
# 1   2002    829
# 2   2003    775
# 3   2004    744
# 0   2005    936

# %%
global_sales_yearupto2005 = df_upto2005.groupby('Year')['Global_Sales'].sum().reset_index()
global_sales_yearupto2005
# Out:
#     Year  Global_Sales
# 0   1980         11.38
# 1   1981         35.77
# 2   1982         28.86
# 3   1983         16.79
# 4   1984         50.36
# 5   1985         53.94
# 6   1986         37.07
# 7   1987         21.74
# 8   1988         47.22
# 9   1989         73.45
# 10  1990         49.39
# 11  1991         32.23
# 12  1992         76.16
# 13  1993         45.98
# 14  1994         79.17
# 15  1995         88.11
# 16  1996        199.15
# 17  1997        200.98
# 18  1998        256.47
# 19  1999        251.27
# 20  2000        201.56
# 21  2001        331.47
# 22  2002        395.52
# 23  2003        357.85
# 24  2004        414.01
# 25  2005        458.51

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'Global_Sales', data = global_sales_yearupto2005)
plt.title('Global Sales from 1980 to 2005',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Global Sales from 1980 to 2005',bbox_inches='tight')
plt.show()

# %% [markdown]
# ###CORRELATION BETWEEN GAME RELEASE COUNT AND SALES (1980 - 2005)

# %%
sales_count_df = pd.merge(global_sales_yearupto2005,gc_df)
sales_count_df
# Out:
#     Year  Global_Sales  Count
# 0   1980         11.38      9
# 1   1981         35.77     46
# 2   1982         28.86     36
# 3   1983         16.79     17
# 4   1984         50.36     14
# 5   1985         53.94     14
# 6   1986         37.07     21
# 7   1987         21.74     16
# 8   1988         47.22     15
# 9   1989         73.45     17
# 10  1990         49.39     16
# 11  1991         32.23     41
# 12  1992         76.16     43
# 13  1993         45.98     60
# 14  1994         79.17    121
# 15  1995         88.11    219
# 16  1996        199.15    263
# 17  1997        200.98    289
# 18  1998        256.47    379
# 19  1999        251.27    338
# 20  2000        201.56    349
# 21  2001        331.47    482
# 22  2002        395.52    829
# 23  2003        357.85    775
# 24  2004        414.01    744
# 25  2005        458.51    936

# %%
sales_count_df.corr()
# Out:
#               Global_Sales    Count
# Global_Sales       1.00000  0.97597
# Count              0.97597  1.00000

# %%
plt.figure(figsize=(9,7))
sns.heatmap(sales_count_df.corr(),annot=True)
plt.title('sales and game count from 1980 to 2005',fontsize=20)
plt.savefig('saes and game count from 1980 to 2005',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *As you see, as athe number of game release over the increses the sales also increases. It has a strong corelation of 0.98 to each other. When the game count decreased the sales rate also went down.*

# %% [markdown]
# ###MARKET DISTRIBUTION FROM 1980 TO 2005

# %%
df_upto2005.NA_Sales.sum() + df_upto2005.EU_Sales.sum() + df_upto2005.JP_Sales.sum() + df_upto2005.Other_Sales.sum()
# Out:
# 3812.49

# %%
df_upto2005.Global_Sales.sum()
# Out:
# 3814.41

# %%
mkt_distrb_upto2005 = df_upto2005[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum()
mkt_distrb_upto2005
# Out:
# NA_Sales       1950.40
# EU_Sales        902.74
# JP_Sales        729.34
# Other_Sales     230.01
# dtype: float64

# %%
plt.figure(figsize=(9,7))
plt.pie(mkt_distrb_upto2005,labels=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],autopct='%1.1f%%')
plt.title('Market distribution in the global sales(1980 - 2005)',fontsize=20)
plt.savefig('Market distribution in the Global sales(1980 - 2005)',bbox_inches='tight')
plt.show()

# %%
market_sales_year_upto2005 = df_upto2005.groupby('Year')[['NA_Sales','JP_Sales','EU_Sales','Other_Sales']].sum().reset_index()
market_sales_year_upto2005
# Out:
#     Year  NA_Sales  JP_Sales  EU_Sales  Other_Sales
# 0   1980     10.59      0.00      0.67         0.12
# 1   1981     33.40      0.00      1.96         0.32
# 2   1982     26.92      0.00      1.65         0.31
# 3   1983      7.76      8.10      0.80         0.14
# 4   1984     33.28     14.27      2.10         0.70
# 5   1985     33.73     14.56      4.74         0.92
# 6   1986     12.50     19.81      2.84         1.93
# 7   1987      8.46     11.63      1.41         0.20
# 8   1988     23.87     15.76      6.59         0.99
# 9   1989     45.15     18.36      8.44         1.50
# 10  1990     25.46     14.88      7.63         1.40
# 11  1991     12.76     14.78      3.95         0.74
# 12  1992     33.87     28.91     11.71         1.65
# 13  1993     15.12     25.33      4.65         0.89
# 14  1994     28.15     33.99     14.88         2.20
# 15  1995     24.82     45.75     14.90         2.64
# 16  1996     86.76     57.44     47.26         7.69
# ...

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.lineplot(x = 'Year', y = 'NA_Sales', data = market_sales_year_upto2005, label = 'NA_Sales',color='blue')
sns.lineplot(x = 'Year', y = 'JP_Sales', data = market_sales_year_upto2005, label = 'JP_Sales',color='green')
sns.lineplot(x = 'Year', y = 'EU_Sales', data = market_sales_year_upto2005, label = 'EU_Sales',color='orange')
sns.lineplot(x = 'Year', y = 'Other_Sales', data = market_sales_year_upto2005, label = 'Other_Sales',color='red')
plt.legend()
plt.title('Sales in each Market from 1980 to 2005',fontsize=20)
plt.xticks(rotation = 90)
plt.ylabel('Sales')
plt.savefig('Sales in each Market from 1980 to 2005',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *North America is the biggest video game market in the world. About 50% of the global video games sales are done here.*
# >
# >*Europe is the second largerst with 27% share followed by Japan with 14.5%.*
# >
# >*Only 9% of the global market is shared by the rest of world*

# %% [markdown]
# ##*SALES IN LAST DECADE (2006 - 2016)*

# %% [markdown]
# ###DATA FROM LAST DECADE

# %% [markdown]
# As you can see, from 2017 onwards we don't have enough data on the sales.So when considering the last decade, let's take it from 2006 to 2016.

# %%
decadedf_lst = []
for i in range(2006,2017):
  decadedf_lst.append(df[df.Year== str(i)])
decade_df = pd.concat(decadedf_lst,ignore_index=True)
decade_df
# Out:
#         Rank  ... Global_Sales
# 0          1  ...        82.74
# 1          7  ...        30.01
# 2          8  ...        29.02
# 3         21  ...        18.36
# 4        101  ...         7.31
# ...      ...  ...          ...
# 10193  16565  ...         0.01
# 10194  16572  ...         0.01
# 10195  16573  ...         0.01
# 10196  16579  ...         0.01
# 10197  16592  ...         0.01
#
# [10198 rows x 11 columns]

# %% [markdown]
# ###GLOBAL MARKET

# %% [markdown]
# ####SALES IN YEARS

# %%
d_global_sales_year = decade_df.groupby('Year')['Global_Sales'].sum().reset_index()
d_global_sales_year
# Out:
#     Year  Global_Sales
# 0   2006        521.04
# 1   2007        609.92
# 2   2008        678.90
# 3   2009        667.30
# 4   2010        600.29
# 5   2011        515.80
# 6   2012        363.49
# 7   2013        368.11
# 8   2014        337.03
# 9   2015        264.44
# 10  2016         70.90

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'Global_Sales', data = d_global_sales_year)
plt.title('Global Sales over the Years in last decade',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Global Sales over the Years in last decade',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *During the beginning of this decade the sales in video games were top in the chart.From 2012 onwards there has been a fall in sales to around 50%.*

# %% [markdown]
# ####SALES BY GENRE

# %%
d_global_sales_genre = decade_df.groupby('Genre')['Global_Sales'].sum().reset_index()
d_global_sales_genre
# Out:
#            Genre  Global_Sales
# 0         Action       1122.28
# 1      Adventure        142.67
# 2       Fighting        189.77
# 3           Misc        560.43
# 4       Platform        282.85
# 5         Puzzle         92.03
# 6         Racing        301.79
# 7   Role-Playing        515.02
# 8        Shooter        701.61
# 9     Simulation        222.07
# 10        Sports        793.02
# 11      Strategy         73.68

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'Genre', y = 'Global_Sales', data= d_global_sales_genre)
plt.xticks(rotation= 45)
plt.title('Global Sales vs Genre (Last Decade)',fontsize=20)
plt.savefig('Global Sales vs Genre (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *Sales based on genre is a consistant one for all these years*

# %% [markdown]
# ####TOP PLATFORMS FOR LAST DECADE

# %%
d_top_global_platforms = decade_df.groupby('Platform')['Global_Sales'].sum().reset_index().sort_values('Global_Sales',ascending=False).head(10).reset_index(drop = True)
d_top_global_platforms
# Out:
#   Platform  Global_Sales
# 0     X360        961.28
# 1      PS3        949.35
# 2      Wii        909.81
# 3       DS        669.74
# 4      PS4        278.07
# 5      PS2        265.80
# 6      3DS        246.27
# 7      PSP        240.35
# 8       PC        161.98
# 9     XOne        141.06

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'Global_Sales',x = 'Platform', data = d_top_global_platforms)
plt.title('Top 10 Global Platforms (Last Decade)',fontsize=20)
plt.savefig('Top 10 Global Platforms (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *For the last decade, x360 has rised its sales to the top with a strong competition from ps3 and wii.*

# %% [markdown]
# ####TOP PUBLISHERS FOR LAST DECADE

# %%
d_top_global_publishers = decade_df.groupby('Publisher')['Global_Sales'].sum().reset_index().sort_values('Global_Sales',ascending=False).head(10).reset_index(drop=True)
d_top_global_publishers
# Out:
#                      Publisher  Global_Sales
# 0                     Nintendo        830.96
# 1              Electronic Arts        660.98
# 2                   Activision        522.09
# 3                      Ubisoft        390.17
# 4         Take-Two Interactive        281.73
# 5  Sony Computer Entertainment        258.86
# 6       Microsoft Game Studios        190.84
# 7                          THQ        175.44
# 8                         Sega        163.74
# 9           Namco Bandai Games        143.03

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'Global_Sales', data= d_top_global_publishers)
plt.title('Top 10 Publishers in the world (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the world (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *For all these years, Nintendo has never gave up their competition and remined as the top publisher. Also with Electronic Arts and Activision as their strong competitor.*

# %% [markdown]
# ####TOP GAMES FOR LAST DECADE

# %%
d_top_games = decade_df.head(10)[['Rank','Name','Global_Sales']]
d_top_games
# Out:
#    Rank                                    Name  Global_Sales
# 0     1                              Wii Sports         82.74
# 1     7                   New Super Mario Bros.         30.01
# 2     8                                Wii Play         29.02
# 3    21           Pokemon Diamond/Pokemon Pearl         18.36
# 4   101  The Legend of Zelda: Twilight Princess          7.31
# 5   142                            Gears of War          6.11
# 6   148                       Final Fantasy XII          5.95
# 7   154                            Cooking Mama          5.72
# 8   196                          Guitar Hero II          5.12
# 9   199     Grand Theft Auto: Vice City Stories          5.08

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'Global_Sales', data = d_top_games)
plt.title('Top 10 games in the Global Market (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in the Global Market (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *For these 10 years, Wii Sports had a remarkable sales in the gaming world.*

# %% [markdown]
# ####MARKET DISTRIBUTION FOR LAST DECADE

# %%
d_mkt_distrb = decade_df[['NA_Sales','EU_Sales','JP_Sales','Other_Sales']].sum()
d_mkt_distrb
# Out:
# NA_Sales       2376.98
# EU_Sales       1503.95
# JP_Sales        554.88
# Other_Sales     558.88
# dtype: float64

# %%
plt.figure(figsize=(9,7))
plt.pie(d_mkt_distrb,labels=['NA_Sales','EU_Sales','JP_Sales','Other_Sales'],autopct='%1.1f%%')
plt.title('Market distribution (Last Decade)')
plt.savefig('Market distribution (Last Decade)')
plt.show()

# %% [markdown]
# > *for 10 years, NA holds 47.6% of the global market and Europe in second with 30%.*

# %%
d_market_sales_year = decade_df.groupby('Year')[['NA_Sales','JP_Sales','EU_Sales','Other_Sales']].sum().reset_index()
d_market_sales_year
# Out:
#     Year  NA_Sales  JP_Sales  EU_Sales  Other_Sales
# 0   2006    263.12     73.73    129.24        54.43
# 1   2007    311.18     60.29    160.18        77.58
# 2   2008    351.44     60.26    184.40        82.39
# 3   2009    338.85     61.89    191.59        74.77
# 4   2010    304.24     59.49    176.57        59.90
# 5   2011    241.00     53.04    167.31        54.39
# 6   2012    154.93     51.74    118.76        37.82
# 7   2013    154.77     47.59    125.80        39.82
# 8   2014    131.97     39.46    125.63        40.02
# 9   2015    102.82     33.72     97.71        30.01
# 10  2016     22.66     13.67     26.76         7.75

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.lineplot(x = 'Year', y = 'NA_Sales', data = d_market_sales_year, label = 'NA_Sales',color='blue')
sns.lineplot(x = 'Year', y = 'JP_Sales', data = d_market_sales_year, label = 'JP_Sales',color='green')
sns.lineplot(x = 'Year', y = 'EU_Sales', data = d_market_sales_year, label = 'EU_Sales',color='orange')
sns.lineplot(x = 'Year', y = 'Other_Sales', data = d_market_sales_year, label = 'Other_Sales',color='red')
plt.legend(loc='upper left')
plt.title('Sales in each Market over the years (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.ylabel('Sales')
plt.savefig('Sales in each Market over the years (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# > *when compared to other markets the drop of sales in north america is a drastic one in the last decade.*

# %% [markdown]
# ####GAME RELEASE OVER THE YEARS IN THE LAST DECADE

# %%
plt.figure(figsize= (9,7))
sns.countplot(x = decade_df.Year)
plt.title('Games Release Over Last Decade',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Games Release Over Last Decade',bbox_inches='tight')
plt.show()

# %%
gc_df_ld = decade_df.Year.value_counts().to_frame().reset_index().rename(columns={'index':'Year','Year':'Count'}).sort_values('Year')
gc_df_ld
# Out:
#     Year  Count
# 5   2006   1008
# 3   2007   1201
# 1   2008   1428
# 0   2009   1431
# 2   2010   1257
# 4   2011   1136
# 6   2012    655
# 9   2013    546
# 8   2014    580
# 7   2015    614
# 10  2016    342

# %%
sales_count_df_ld = pd.merge(d_global_sales_year,gc_df_ld)
sales_count_df_ld
# Out:
#     Year  Global_Sales  Count
# 0   2006        521.04   1008
# 1   2007        609.92   1201
# 2   2008        678.90   1428
# 3   2009        667.30   1431
# 4   2010        600.29   1257
# 5   2011        515.80   1136
# 6   2012        363.49    655
# 7   2013        368.11    546
# 8   2014        337.03    580
# 9   2015        264.44    614
# 10  2016         70.90    342

# %%
sales_count_df_ld.corr()
# Out:
#               Global_Sales    Count
# Global_Sales       1.00000  0.95862
# Count              0.95862  1.00000

# %%
plt.figure(figsize=(9,7))
sns.heatmap(sales_count_df_ld.corr(),annot=True)
plt.title('sales and game count in last decade',fontsize=20)
plt.savefig('saes and game count in last decade',bbox_inches='tight')
plt.show()

# %% [markdown]
# >  *as we that the corelation between sale and number of games is high, when the games publishing through out the years decreased the sales also cut down.*

# %% [markdown]
# ###NORTH AMERICA

# %% [markdown]
# ####NA SALES OVER THE YEARS (LAST DECADE)

# %%
d_na_sales_year = decade_df.groupby('Year')['NA_Sales'].sum().reset_index()
d_na_sales_year
# Out:
#     Year  NA_Sales
# 0   2006    263.12
# 1   2007    311.18
# 2   2008    351.44
# 3   2009    338.85
# 4   2010    304.24
# 5   2011    241.00
# 6   2012    154.93
# 7   2013    154.77
# 8   2014    131.97
# 9   2015    102.82
# 10  2016     22.66

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'NA_Sales', data = d_na_sales_year,color='blue')
plt.title('NA Sales over the Years in last decade',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('NA Sales over the Years in last decade',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####NA SALES BASED ON GENRE (LAST DECADE)

# %%
d_na_sales_genre = decade_df.groupby('Genre')['NA_Sales'].sum().reset_index()
d_na_sales_genre
# Out:
#            Genre  NA_Sales
# 0         Action    529.02
# 1      Adventure     62.01
# 2       Fighting     94.54
# 3           Misc    287.07
# 4       Platform    135.65
# 5         Puzzle     43.34
# 6         Racing    132.90
# 7   Role-Playing    196.06
# 8        Shooter    363.49
# 9     Simulation    108.78
# 10        Sports    395.53
# 11      Strategy     28.59

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'Genre', y = 'NA_Sales', data= d_na_sales_genre,color='blue')
plt.xticks(rotation= 45)
plt.title('NA Sales vs Genre (Last Decade)',fontsize=20)
plt.savefig('NA Sales vs Genre (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PLATFORMS IN NA (LAST DECADE)

# %%
d_top_na_platforms = decade_df.groupby('Platform')['NA_Sales'].sum().reset_index().sort_values('NA_Sales',ascending=False).head(10).reset_index(drop = True)
d_top_na_platforms
# Out:
#   Platform  NA_Sales
# 0     X360    587.44
# 1      Wii    497.37
# 2      PS3    388.90
# 3       DS    331.37
# 4      PS2    114.89
# 5      PS4     96.80
# 6     XOne     83.19
# 7      PSP     80.36
# 8      3DS     78.03
# 9       PC     43.23

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'NA_Sales',x = 'Platform', data = d_top_na_platforms,color='blue')
plt.title('Top 10 NA Platforms (Last Decade)',fontsize=20)
plt.savefig('Top 10 NA Platforms (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PUBLISHERS IN NA (LAST DECADE)

# %%
d_top_na_publishers = decade_df.groupby('Publisher')['NA_Sales'].sum().reset_index().sort_values('NA_Sales',ascending=False).head(10).reset_index(drop=True)
d_top_na_publishers
# Out:
#                                 Publisher  NA_Sales
# 0                                Nintendo    337.78
# 1                         Electronic Arts    318.17
# 2                              Activision    299.81
# 3                                 Ubisoft    203.62
# 4                    Take-Two Interactive    158.33
# 5                  Microsoft Game Studios    115.70
# 6                                     THQ    107.14
# 7             Sony Computer Entertainment    106.28
# 8  Warner Bros. Interactive Entertainment     74.93
# 9              Disney Interactive Studios     62.49

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'NA_Sales', data= d_top_na_publishers,color='blue')
plt.title('Top 10 Publishers in the NA (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the NA (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP GAMES IN NA (LAST DECADE)

# %%
d_top_games_na = decade_df.head(10)[['Rank','Name','NA_Sales']]
d_top_games_na
# Out:
#    Rank                                    Name  NA_Sales
# 0     1                              Wii Sports     41.49
# 1     7                   New Super Mario Bros.     11.38
# 2     8                                Wii Play     14.03
# 3    21           Pokemon Diamond/Pokemon Pearl      6.42
# 4   101  The Legend of Zelda: Twilight Princess      3.83
# 5   142                            Gears of War      3.54
# 6   148                       Final Fantasy XII      1.88
# 7   154                            Cooking Mama      3.13
# 8   196                          Guitar Hero II      3.81
# 9   199     Grand Theft Auto: Vice City Stories      1.70

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'NA_Sales', data = d_top_games_na,color='blue')
plt.title('Top 10 games in the NA Market (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in the NA Market (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ###EUROPE

# %% [markdown]
# ####EU SALES OVER THE YEARS (LAST DECADE)

# %%
d_eu_sales_year = decade_df.groupby('Year')['EU_Sales'].sum().reset_index()
d_eu_sales_year
# Out:
#     Year  EU_Sales
# 0   2006    129.24
# 1   2007    160.18
# 2   2008    184.40
# 3   2009    191.59
# 4   2010    176.57
# 5   2011    167.31
# 6   2012    118.76
# 7   2013    125.80
# 8   2014    125.63
# 9   2015     97.71
# 10  2016     26.76

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'EU_Sales', data = d_eu_sales_year,color='orange')
plt.title('EU Sales over the Years in last decade',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('EU Sales over the Years in last decade',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####EU SALES BASED ON GENRE (LAST DECADE)

# %%
d_eu_sales_genre = decade_df.groupby('Genre')['EU_Sales'].sum().reset_index()
d_eu_sales_genre
# Out:
#            Genre  EU_Sales
# 0         Action    356.11
# 1      Adventure     38.47
# 2       Fighting     43.62
# 3           Misc    149.67
# 4       Platform     82.77
# 5         Puzzle     28.48
# 6         Racing    115.01
# 7   Role-Playing    109.90
# 8        Shooter    234.80
# 9     Simulation     69.24
# 10        Sports    251.52
# 11      Strategy     24.36

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'Genre', y = 'EU_Sales', data= d_eu_sales_genre,color='orange')
plt.xticks(rotation= 45)
plt.title('EU Sales vs Genre (Last Decade)',fontsize=20)
plt.savefig('EU Sales vs Genre (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PLATFORMS IN EU (LAST DECADE)

# %%
d_top_eu_platforms = decade_df.groupby('Platform')['EU_Sales'].sum().reset_index().sort_values('EU_Sales',ascending=False).head(10).reset_index(drop = True)
d_top_eu_platforms
# Out:
#   Platform  EU_Sales
# 0      PS3    340.47
# 1     X360    277.49
# 2      Wii    264.35
# 3       DS    148.02
# 4      PS4    123.70
# 5       PC     97.36
# 6      3DS     58.29
# 7      PSP     55.53
# 8      PS2     46.28
# 9     XOne     45.65

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'EU_Sales',x = 'Platform', data = d_top_eu_platforms,color='orange')
plt.title('Top 10 EU Platforms (Last Decade)',fontsize=20)
plt.savefig('Top 10 EU Platforms (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PUBLISHERS IN EU (LAST DECADE)

# %%
d_top_eu_publishers = decade_df.groupby('Publisher')['EU_Sales'].sum().reset_index().sort_values('EU_Sales',ascending=False).head(10).reset_index(drop=True)
d_top_eu_publishers
# Out:
#                                 Publisher  EU_Sales
# 0                         Electronic Arts    243.79
# 1                                Nintendo    235.34
# 2                              Activision    153.20
# 3                                 Ubisoft    137.25
# 4             Sony Computer Entertainment     91.16
# 5                    Take-Two Interactive     84.95
# 6                                    Sega     60.88
# 7                  Microsoft Game Studios     55.92
# 8  Warner Bros. Interactive Entertainment     48.59
# 9                                     THQ     45.54

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'EU_Sales', data= d_top_eu_publishers,color='orange')
plt.title('Top 10 Publishers in the EU (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the EU (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP GAMES IN EU (LAST DACADE)

# %%
d_top_games_eu = decade_df.head(10)[['Rank','Name','EU_Sales']]
d_top_games_eu
# Out:
#    Rank                                    Name  EU_Sales
# 0     1                              Wii Sports     29.02
# 1     7                   New Super Mario Bros.      9.23
# 2     8                                Wii Play      9.20
# 3    21           Pokemon Diamond/Pokemon Pearl      4.52
# 4   101  The Legend of Zelda: Twilight Princess      2.19
# 5   142                            Gears of War      1.90
# 6   148                       Final Fantasy XII      0.00
# 7   154                            Cooking Mama      1.94
# 8   196                          Guitar Hero II      0.63
# 9   199     Grand Theft Auto: Vice City Stories      2.02

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'EU_Sales', data = d_top_games_eu,color='orange')
plt.title('Top 10 games in the EU Market (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in the EU Market (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ###JAPAN

# %% [markdown]
# ####JP SALES OVER THE YEARS (LAST DECADE)

# %%
d_jp_sales_year = decade_df.groupby('Year')['JP_Sales'].sum().reset_index()
d_jp_sales_year
# Out:
#     Year  JP_Sales
# 0   2006     73.73
# 1   2007     60.29
# 2   2008     60.26
# 3   2009     61.89
# 4   2010     59.49
# 5   2011     53.04
# 6   2012     51.74
# 7   2013     47.59
# 8   2014     39.46
# 9   2015     33.72
# 10  2016     13.67

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'JP_Sales', data = d_jp_sales_year,color='green')
plt.title('JP Sales over the Years in last decade',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('JP Sales over the Years in last decade',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####JP SALES BASED ON GENRE (LAST DECADE)

# %%
d_jp_sales_genre = decade_df.groupby('Genre')['JP_Sales'].sum().reset_index()
d_jp_sales_genre
# Out:
#            Genre  JP_Sales
# 0         Action    100.57
# 1      Adventure     29.28
# 2       Fighting     28.48
# 3           Misc     64.18
# 4       Platform     35.14
# 5         Puzzle     12.43
# 6         Racing     13.17
# 7   Role-Playing    167.24
# 8        Shooter     18.85
# 9     Simulation     23.21
# 10        Sports     48.80
# 11      Strategy     13.53

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'Genre', y = 'JP_Sales', data= d_jp_sales_genre,color='green')
plt.xticks(rotation= 45)
plt.title('JP Sales vs Genre (Last Decade)',fontsize=20)
plt.savefig('JP Sales vs Genre (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PLATFORMS IN JP (LAST DECADE)

# %%
d_top_jp_platforms = decade_df.groupby('Platform')['JP_Sales'].sum().reset_index().sort_values('JP_Sales',ascending=False).head(10).reset_index(drop = True)
d_top_jp_platforms
# Out:
#   Platform  JP_Sales
# 0       DS    141.49
# 1      3DS     97.30
# 2      PS3     79.21
# 3      PSP     70.63
# 4      Wii     68.28
# 5      PS2     35.93
# 6      PSV     20.84
# 7      PS4     14.27
# 8     WiiU     12.79
# 9     X360     12.02

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'JP_Sales',x = 'Platform', data = d_top_jp_platforms,color='green')
plt.title('Top 10 JP Platforms (Last Decade)',fontsize=20)
plt.savefig('Top 10 JP Platforms (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PUBLISHERS IN JP (LAST DECADE)

# %%
d_top_jp_publishers = decade_df.groupby('Publisher')['JP_Sales'].sum().reset_index().sort_values('JP_Sales',ascending=False).head(10).reset_index(drop=True)
d_top_jp_publishers
# Out:
#                       Publisher  JP_Sales
# 0                      Nintendo    195.04
# 1            Namco Bandai Games     69.80
# 2                   Square Enix     40.94
# 3                        Capcom     36.91
# 4  Konami Digital Entertainment     36.46
# 5                          Sega     23.75
# 6                    Tecmo Koei     16.70
# 7   Sony Computer Entertainment     14.35
# 8                       Level 5     11.65
# 9               Electronic Arts      6.24

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'JP_Sales', data= d_top_jp_publishers,color='green')
plt.title('Top 10 Publishers in the JP (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the JP (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP GAMES IN JP (LAST DECADE)

# %%
d_top_games_jp = decade_df.head(10)[['Rank','Name','JP_Sales']]
d_top_games_jp
# Out:
#    Rank                                    Name  JP_Sales
# 0     1                              Wii Sports      3.77
# 1     7                   New Super Mario Bros.      6.50
# 2     8                                Wii Play      2.93
# 3    21           Pokemon Diamond/Pokemon Pearl      6.04
# 4   101  The Legend of Zelda: Twilight Princess      0.60
# 5   142                            Gears of War      0.07
# 6   148                       Final Fantasy XII      2.33
# 7   154                            Cooking Mama      0.07
# 8   196                          Guitar Hero II      0.00
# 9   199     Grand Theft Auto: Vice City Stories      0.16

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'JP_Sales', data = d_top_games_jp,color = 'green')
plt.title('Top 10 games in the JP Market (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in the JP Market (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ###OTHER

# %% [markdown]
# ####SALES OVER THE YEARS - OTHER (LAST DECADE)

# %%
d_other_sales_year = decade_df.groupby('Year')['Other_Sales'].sum().reset_index()
d_other_sales_year
# Out:
#     Year  Other_Sales
# 0   2006        54.43
# 1   2007        77.58
# 2   2008        82.39
# 3   2009        74.77
# 4   2010        59.90
# 5   2011        54.39
# 6   2012        37.82
# 7   2013        39.82
# 8   2014        40.02
# 9   2015        30.01
# 10  2016         7.75

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Year', y = 'Other_Sales', data = d_other_sales_year,color='red')
plt.title('Other Sales over the Years in last decade',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Other Sales over the Years in last decade',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####SALES BASED ON GENRE - OTHER (LAST DECADE)

# %%
d_other_sales_genre = decade_df.groupby('Genre')['Other_Sales'].sum().reset_index()
d_other_sales_genre
# Out:
#            Genre  Other_Sales
# 0         Action       136.09
# 1      Adventure        12.73
# 2       Fighting        23.18
# 3           Misc        59.28
# 4       Platform        29.11
# 5         Puzzle         7.40
# 6         Racing        40.57
# 7   Role-Playing        41.68
# 8        Shooter        84.19
# 9     Simulation        20.52
# 10        Sports        97.12
# 11      Strategy         7.01

# %%
plt.figure(figsize=(12,8))
sns.barplot(x = 'Genre', y = 'Other_Sales', data= d_other_sales_genre,color='red')
plt.xticks(rotation= 45)
plt.title('Other Sales vs Genre (Last Decade)',fontsize=20)
plt.savefig('Other Sales vs Genre (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PLATFORMS - OTHER (LAST DECADE)

# %%
d_top_other_platforms = decade_df.groupby('Platform')['Other_Sales'].sum().reset_index().sort_values('Other_Sales',ascending=False).head(10).reset_index(drop = True)
d_top_other_platforms
# Out:
#   Platform  Other_Sales
# 0      PS3       140.81
# 1     X360        84.04
# 2      Wii        79.20
# 3      PS2        68.70
# 4       DS        47.99
# 5      PS4        43.36
# 6      PSP        33.87
# 7       PC        20.85
# 8      3DS        12.55
# 9     XOne        11.92

# %%
plt.figure(figsize=(12,8))
sns.barplot(y = 'Other_Sales',x = 'Platform', data = d_top_other_platforms,color='red')
plt.title('Top 10 Platforms in Other market (Last Decade)',fontsize=20)
plt.savefig('Top 10 Platforms in Other market(Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP PUBLISHERS - OTHER (LAST DECADE)

# %%
d_top_other_publishers = decade_df.groupby('Publisher')['Other_Sales'].sum().reset_index().sort_values('Other_Sales',ascending=False).head(10).reset_index(drop=True)
d_top_other_publishers
# Out:
#                                 Publisher  Other_Sales
# 0                         Electronic Arts        92.67
# 1                              Activision        63.52
# 2                                Nintendo        62.69
# 3             Sony Computer Entertainment        47.05
# 4                                 Ubisoft        44.22
# 5                    Take-Two Interactive        34.33
# 6                                     THQ        21.84
# 7                                    Sega        19.48
# 8            Konami Digital Entertainment        18.15
# 9  Warner Bros. Interactive Entertainment        17.07

# %%
plt.figure(figsize=(12,8))
plt.grid(True)
sns.barplot(x = 'Publisher', y = 'Other_Sales', data= d_top_other_publishers,color='red')
plt.title('Top 10 Publishers in the Other markets (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 Publishers in the Other markets (Last Decade)',bbox_inches='tight')
plt.show()

# %% [markdown]
# ####TOP GAMES - OTHER (LAST DECADE)

# %%
d_top_games_other = decade_df.head(10)[['Rank','Name','Other_Sales']]
d_top_games_other
# Out:
#    Rank                                    Name  Other_Sales
# 0     1                              Wii Sports         8.46
# 1     7                   New Super Mario Bros.         2.90
# 2     8                                Wii Play         2.85
# 3    21           Pokemon Diamond/Pokemon Pearl         1.37
# 4   101  The Legend of Zelda: Twilight Princess         0.70
# 5   142                            Gears of War         0.60
# 6   148                       Final Fantasy XII         1.74
# 7   154                            Cooking Mama         0.58
# 8   196                          Guitar Hero II         0.68
# 9   199     Grand Theft Auto: Vice City Stories         1.21

# %%
plt.figure(figsize=(10,8))
sns.barplot(x = 'Name', y = 'Other_Sales', data = d_top_games_other,color='red')
plt.title('Top 10 games in the Other Markets (Last Decade)',fontsize=20)
plt.xticks(rotation = 90)
plt.savefig('Top 10 games in the Other Markets (Last Decade)',bbox_inches='tight')
plt.show()
